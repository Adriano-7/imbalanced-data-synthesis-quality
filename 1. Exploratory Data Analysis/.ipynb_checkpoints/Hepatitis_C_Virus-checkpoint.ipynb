# %% [markdown]
# # Exploratory Data Analysis: Hepatitis C Virus (HCV) in Egyptian Patients
#
# The "Hepatitis C Virus (HCV) for Egyptian patients" dataset from the UCI Machine Learning Repository contains clinical and demographic data for Egyptian patients who underwent treatment for HCV over 18 months. It includes a variety of features, from basic demographics and symptoms to complex blood work results like liver enzyme levels and RNA measurements.
#
# The target variable for our analysis is the **Baseline Histological Staging**, which represents the severity of liver fibrosis, graded from F1 to F4 (Cirrhosis).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 7)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
import pandas as pd

file_path = "HCV-Egy-Data.csv"

df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "nourmibrahim/hepatitis-c-virus-hcv-for-egyptian-patients",
  file_path,
)

print("First 5 rows of the dataset:")
display(df.head())

print(f"\nDataset shape: {df.shape}\n")
print("Dataset Information:")
df.info()
# Out:
# /tmp/ipykernel_20593/2971834711.py:7: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# First 5 rows of the dataset:
#    Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0    56       1   35      2               1          1          1
# 1    46       1   29      1               2          2          1
# 2    57       1   33      2               2          2          2
# 3    49       2   33      1               2          1          2
# 4    59       1   32      1               1          2          1
#
#    Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  ALT 36  \
# 0                                 2          2                 2  ...       5
# 1                                 2          2                 1  ...      57
# 2                                 1          1                 1  ...       5
# 3                                 1          2                 1  ...      48
# 4                                 2          2                 2  ...      94
#
#    ALT 48  ALT after 24 w  RNA Base   RNA 4   RNA 12  RNA EOT  RNA EF  \
# 0       5               5    655330  634536   288194        5       5
# 1     123              44     40620  538635   637056   336804   31085
# 2       5               5    571148  661346        5   735945  558829
# 3      77              33   1041941  449939   585688   744463  582301
# 4      90              30    660410  738756  3731527   338946  242861
#
#    Baseline histological Grading  Baselinehistological staging
# 0                             13                             2
# 1                              4                             2
# 2                              4                             4
# 3                             10                             3
# 4                             11                             1
#
# [5 rows x 29 columns]
# Dataset shape: (1385, 29)
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1385 entries, 0 to 1384
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               1385 non-null   int64
#  1   Gender                            1385 non-null   int64
#  2   BMI                               1385 non-null   int64
#  3   Fever                             1385 non-null   int64
#  4   Nausea/Vomting                    1385 non-null   int64
#  5   Headache                          1385 non-null   int64
#  6   Diarrhea                          1385 non-null   int64
#  7   Fatigue & generalized bone ache   1385 non-null   int64
#  8   Jaundice                          1385 non-null   int64
#  9   Epigastric pain                   1385 non-null   int64
#  10  WBC                               1385 non-null   int64
#  11  RBC                               1385 non-null   float64
#  12  HGB                               1385 non-null   int64
#  13  Plat                              1385 non-null   float64
#  14  AST 1                             1385 non-null   int64
#  15  ALT 1                             1385 non-null   int64
#  16  ALT4                              1385 non-null   float64
#  17  ALT 12                            1385 non-null   int64
#  18  ALT 24                            1385 non-null   int64
#  19  ALT 36                            1385 non-null   int64
#  20  ALT 48                            1385 non-null   int64
#  21  ALT after 24 w                    1385 non-null   int64
#  22  RNA Base                          1385 non-null   int64
#  23  RNA 4                             1385 non-null   int64
#  24  RNA 12                            1385 non-null   int64
#  25  RNA EOT                           1385 non-null   int64
#  26  RNA EF                            1385 non-null   int64
#  27  Baseline histological Grading     1385 non-null   int64
#  28  Baselinehistological staging      1385 non-null   int64
# dtypes: float64(3), int64(26)
# memory usage: 313.9 KB

# %% [markdown]
# * **Dataset Size:** The dataset contains **1385 records (patients)** and **29 columns (features)**. This is a moderately sized dataset, sufficient for initial modeling.
#
# * **Data Completeness:** All 29 columns have **1385 non-null values**. This means there are **no missing values** in the dataset, which significantly simplifies the data cleaning process.
#
# * **Data Types:** All features are of a numerical data type (`int64` or `float64`). This indicates that categorical features like `Gender` and binary symptoms (`Fever`, `Jaundice`, etc.) have already been **numerically encoded** (e.g., as 1 and 2).
#
# * **Column Naming:** The **column names need cleaning and standardization**. We can observe several issues:
#     * A typo in `Nausea/Vomting`.
#     * Inconsistent spacing in `ALT` columns (`ALT 1` vs. `ALT4`).
#     * A very long name in `Fatigue & generalized bone ache`.
#     * A run-on word in `Baselinehistological staging`.
#
# Our immediate next step will be to address these naming inconsistencies to make data manipulation easier.

# %%
rename_map = {
    'Nausea/Vomting': 'Nausea/Vomiting',
    'Fatigue & generalized bone ache': 'Fatigue_Bone_Ache',
    'Epigastric pain': 'Epigastric_Pain',
    'AST 1': 'AST_1',
    'ALT 1': 'ALT_1',
    'ALT4': 'ALT_4',
    'ALT 12': 'ALT_12',
    'ALT 24': 'ALT_24',
    'ALT 36': 'ALT_36',
    'ALT 48': 'ALT_48',
    'ALT after 24 w': 'ALT_Post_24w',
    'RNA Base': 'RNA_Base',
    'RNA 4': 'RNA_4',
    'RNA 12': 'RNA_12',
    'RNA EOT': 'RNA_EOT',
    'RNA EF': 'RNA_EF',
    'Baseline histological Grading': 'Histological_Grading',
    'Baselinehistological staging': 'Fibrosis_Stage' # This is the target variable
}

# Apply the renaming
df.rename(columns=rename_map, inplace=True)

# Verify the changes by printing the new column names
print("Successfully cleaned column names:")
print(df.columns.tolist())

print("\nCleaned DataFrame head:")
display(df.head())
# Out:
# Successfully cleaned column names:
# ['Age', 'Gender', 'BMI', 'Fever', 'Nausea/Vomiting', 'Headache', 'Diarrhea', 'Fatigue_Bone_Ache', 'Jaundice', 'Epigastric_Pain', 'WBC', 'RBC', 'HGB', 'Plat', 'AST_1', 'ALT_1', 'ALT_4', 'ALT_12', 'ALT_24', 'ALT_36', 'ALT_48', 'ALT_Post_24w', 'RNA_Base', 'RNA_4', 'RNA_12', 'RNA_EOT', 'RNA_EF', 'Histological_Grading', 'Fibrosis_Stage']
#
# Cleaned DataFrame head:
#    Age  Gender  BMI  Fever  Nausea/Vomiting  Headache  Diarrhea  \
# 0   56       1   35      2                1         1         1
# 1   46       1   29      1                2         2         1
# 2   57       1   33      2                2         2         2
# 3   49       2   33      1                2         1         2
# 4   59       1   32      1                1         2         1
#
#    Fatigue_Bone_Ache  Jaundice  Epigastric_Pain  ...  ALT_36  ALT_48  \
# 0                  2         2                2  ...       5       5
# 1                  2         2                1  ...      57     123
# 2                  1         1                1  ...       5       5
# 3                  1         2                1  ...      48      77
# 4                  2         2                2  ...      94      90
#
#    ALT_Post_24w  RNA_Base   RNA_4   RNA_12  RNA_EOT  RNA_EF  \
# 0             5    655330  634536   288194        5       5
# 1            44     40620  538635   637056   336804   31085
# 2             5    571148  661346        5   735945  558829
# 3            33   1041941  449939   585688   744463  582301
# 4            30    660410  738756  3731527   338946  242861
#
#    Histological_Grading  Fibrosis_Stage
# 0                    13               2
# 1                     4               2
# 2                     4               4
# 3                    10               3
# 4                    11               1
#
# [5 rows x 29 columns]

# %%
# Decode Gender (Assuming 1: Male, 2: Female)
df['Gender'] = df['Gender'].map({1: 'Male', 2: 'Female'})

# Decode all binary symptom columns (Assuming 1: Absent, 2: Present)
symptom_cols = [
    'Fever', 'Nausea/Vomiting', 'Headache', 'Diarrhea', 
    'Fatigue_Bone_Ache', 'Jaundice', 'Epigastric_Pain'
]
for col in symptom_cols:
    df[col] = df[col].map({1: 'Absent', 2: 'Present'})

# Map the target variable to its clinical meaning
df['Fibrosis_Stage_Label'] = df['Fibrosis_Stage'].map({
    1: 'F1 (Portal Fibrosis)',
    2: 'F2 (Few Septa)',
    3: 'F3 (Many Septa)',
    4: 'F4 (Cirrhosis)'
})

print("Data successfully decoded for categorical features.")

# Statistics
print("\nDescriptive Statistics for Numerical Features:")
display(df.describe().drop(columns=['Fibrosis_Stage']).T.style.background_gradient(cmap='viridis'))
# Out:
# Data successfully decoded for categorical features.
#
# Descriptive Statistics for Numerical Features:
# <style type="text/css">
# #T_cd79f_row0_col0, #T_cd79f_row0_col1, #T_cd79f_row0_col2, #T_cd79f_row0_col3, #T_cd79f_row0_col4, #T_cd79f_row0_col5, #T_cd79f_row0_col6, #T_cd79f_row0_col7, #T_cd79f_row1_col0, #T_cd79f_row1_col1, #T_cd79f_row1_col2, #T_cd79f_row1_col3, #T_cd79f_row1_col4, #T_cd79f_row1_col5, #T_cd79f_row1_col6, #T_cd79f_row1_col7, #T_cd79f_row2_col0, #T_cd79f_row2_col1, #T_cd79f_row2_col3, #T_cd79f_row2_col4, #T_cd79f_row2_col5, #T_cd79f_row2_col6, #T_cd79f_row2_col7, #T_cd79f_row3_col0, #T_cd79f_row4_col0, #T_cd79f_row4_col1, #T_cd79f_row4_col2, #T_cd79f_row4_col3, #T_cd79f_row4_col4, #T_cd79f_row4_col5, #T_cd79f_row4_col6, #T_cd79f_row4_col7, #T_cd79f_row5_col0, #T_cd79f_row6_col0, #T_cd79f_row6_col1, #T_cd79f_row6_col2, #T_cd79f_row6_col3, #T_cd79f_row6_col4, #T_cd79f_row6_col5, #T_cd79f_row6_col6, #T_cd79f_row6_col7, #T_cd79f_row7_col0, #T_cd79f_row7_col1, #T_cd79f_row7_col2, #T_cd79f_row7_col3, #T_cd79f_row7_col4, #T_cd79f_row7_col5, #T_cd79f_row7_col6, #T_cd79f_row7_col7, #T_cd79f_row8_col0, #T_cd79f_row8_col1, #T_cd79f_row8_col2, #T_cd79f_row8_col3, #T_cd79f_row8_col4, #T_cd79f_row8_col5, #T_cd79f_row8_col6, #T_cd79f_row8_col7, #T_cd79f_row9_col0, #T_cd79f_row9_col1, #T_cd79f_row9_col2, #T_cd79f_row9_col3, #T_cd79f_row9_col4, #T_cd79f_row9_col5, #T_cd79f_row9_col6, #T_cd79f_row9_col7, #T_cd79f_row10_col0, #T_cd79f_row10_col1, #T_cd79f_row10_col2, #T_cd79f_row10_col3, #T_cd79f_row10_col4, #T_cd79f_row10_col5, #T_cd79f_row10_col6, #T_cd79f_row10_col7, #T_cd79f_row11_col0, #T_cd79f_row11_col1, #T_cd79f_row11_col2, #T_cd79f_row11_col3, #T_cd79f_row11_col4, #T_cd79f_row11_col5, #T_cd79f_row11_col6, #T_cd79f_row11_col7, #T_cd79f_row12_col0, #T_cd79f_row12_col1, #T_cd79f_row12_col2, #T_cd79f_row12_col3, #T_cd79f_row12_col4, #T_cd79f_row12_col5, #T_cd79f_row12_col6, #T_cd79f_row12_col7, #T_cd79f_row13_col0, #T_cd79f_row13_col1, #T_cd79f_row13_col2, #T_cd79f_row13_col3, #T_cd79f_row13_col4, #T_cd79f_row13_col5, #T_cd79f_row13_col6, #T_cd79f_row13_col7, #T_cd79f_row14_col0, #T_cd79f_row14_col3, #T_cd79f_row15_col0, #T_cd79f_row15_col3, #T_cd79f_row16_col0, #T_cd79f_row16_col3, #T_cd79f_row16_col4, #T_cd79f_row17_col0, #T_cd79f_row17_col3, #T_cd79f_row17_col4, #T_cd79f_row18_col0, #T_cd79f_row18_col3, #T_cd79f_row18_col4, #T_cd79f_row19_col0, #T_cd79f_row19_col1, #T_cd79f_row19_col2, #T_cd79f_row19_col3, #T_cd79f_row19_col4, #T_cd79f_row19_col5, #T_cd79f_row19_col6, #T_cd79f_row19_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_cd79f_row2_col2 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_cd79f_row3_col1, #T_cd79f_row3_col3, #T_cd79f_row3_col4, #T_cd79f_row3_col5, #T_cd79f_row3_col6, #T_cd79f_row3_col7, #T_cd79f_row15_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_cd79f_row3_col2 {
#   background-color: #e2e418;
#   color: #000000;
# }
# #T_cd79f_row5_col1, #T_cd79f_row5_col5 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_cd79f_row5_col2 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_cd79f_row5_col3 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_cd79f_row5_col4 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_cd79f_row5_col6 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_cd79f_row5_col7 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_cd79f_row14_col1, #T_cd79f_row14_col5, #T_cd79f_row15_col1, #T_cd79f_row15_col5 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_cd79f_row14_col2 {
#   background-color: #f1e51d;
#   color: #000000;
# }
# #T_cd79f_row14_col4, #T_cd79f_row15_col4, #T_cd79f_row16_col1, #T_cd79f_row17_col1, #T_cd79f_row18_col1 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_cd79f_row14_col6 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_cd79f_row14_col7, #T_cd79f_row15_col7 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_cd79f_row15_col6 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_cd79f_row16_col2 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_cd79f_row16_col5 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_cd79f_row16_col6, #T_cd79f_row17_col6, #T_cd79f_row18_col6 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_cd79f_row16_col7 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_cd79f_row17_col2 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_cd79f_row17_col5, #T_cd79f_row18_col5 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_cd79f_row17_col7, #T_cd79f_row18_col7 {
#   background-color: #453882;
#   color: #f1f1f1;
# }
# #T_cd79f_row18_col2 {
#   background-color: #58c765;
#   color: #000000;
# }
# </style>
# <table id="T_cd79f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd79f_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_cd79f_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_cd79f_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_cd79f_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_cd79f_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_cd79f_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_cd79f_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_cd79f_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd79f_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_cd79f_row0_col0" class="data row0 col0" >1385.000000</td>
#       <td id="T_cd79f_row0_col1" class="data row0 col1" >46.319134</td>
#       <td id="T_cd79f_row0_col2" class="data row0 col2" >8.781506</td>
#       <td id="T_cd79f_row0_col3" class="data row0 col3" >32.000000</td>
#       <td id="T_cd79f_row0_col4" class="data row0 col4" >39.000000</td>
#       <td id="T_cd79f_row0_col5" class="data row0 col5" >46.000000</td>
#       <td id="T_cd79f_row0_col6" class="data row0 col6" >54.000000</td>
#       <td id="T_cd79f_row0_col7" class="data row0 col7" >61.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cd79f_level0_row1" class="row_heading level0 row1" >BMI</th>
#       <td id="T_cd79f_row1_col0" class="data row1 col0" >1385.000000</td>
#       <td id="T_cd79f_row1_col1" class="data row1 col1" >28.608664</td>
#       <td id="T_cd79f_row1_col2" class="data row1 col2" >4.076215</td>
#       <td id="T_cd79f_row1_col3" class="data row1 col3" >22.000000</td>
#       <td id="T_cd79f_row1_col4" class="data row1 col4" >25.000000</td>
#       <td id="T_cd79f_row1_col5" class="data row1 col5" >29.000000</td>
#       <td id="T_cd79f_row1_col6" class="data row1 col6" >32.000000</td>
#       <td id="T_cd79f_row1_col7" class="data row1 col7" >35.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cd79f_level0_row2" class="row_heading level0 row2" >WBC</th>
#       <td id="T_cd79f_row2_col0" class="data row2 col0" >1385.000000</td>
#       <td id="T_cd79f_row2_col1" class="data row2 col1" >7533.386282</td>
#       <td id="T_cd79f_row2_col2" class="data row2 col2" >2668.220333</td>
#       <td id="T_cd79f_row2_col3" class="data row2 col3" >2991.000000</td>
#       <td id="T_cd79f_row2_col4" class="data row2 col4" >5219.000000</td>
#       <td id="T_cd79f_row2_col5" class="data row2 col5" >7498.000000</td>
#       <td id="T_cd79f_row2_col6" class="data row2 col6" >9902.000000</td>
#       <td id="T_cd79f_row2_col7" class="data row2 col7" >12101.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cd79f_level0_row3" class="row_heading level0 row3" >RBC</th>
#       <td id="T_cd79f_row3_col0" class="data row3 col0" >1385.000000</td>
#       <td id="T_cd79f_row3_col1" class="data row3 col1" >4422129.610830</td>
#       <td id="T_cd79f_row3_col2" class="data row3 col2" >346357.711599</td>
#       <td id="T_cd79f_row3_col3" class="data row3 col3" >3816422.000000</td>
#       <td id="T_cd79f_row3_col4" class="data row3 col4" >4121374.000000</td>
#       <td id="T_cd79f_row3_col5" class="data row3 col5" >4438465.000000</td>
#       <td id="T_cd79f_row3_col6" class="data row3 col6" >4721279.000000</td>
#       <td id="T_cd79f_row3_col7" class="data row3 col7" >5018451.000000</td>
#     </tr>
#     <tr>

# %%
fig = px.pie(
    df, 
    names='Fibrosis_Stage_Label', 
    title='Distribution of Liver Fibrosis Stages (Target Variable)',
    hole=0.3,
    color_discrete_sequence=px.colors.sequential.Plasma_r
)

fig.update_traces(
    textposition='inside', 
    textinfo='percent+label',
    hovertemplate='Stage: %{label}<br>Count: %{value}<br>Percentage: %{percent}'
)
fig.update_layout(showlegend=False)
fig.show()

# %%
fig = make_subplots(
    rows=1, cols=3,
    specs=[[{'type':'xy'}, {'type':'xy'}, {'type':'domain'}]],
    subplot_titles=('Age Distribution', 'BMI Distribution', 'Gender Distribution')
)

# Age Histogram (xy type)
fig.add_trace(go.Histogram(x=df['Age'], name='Age', marker_color='#636EFA'), row=1, col=1)

# BMI Histogram (xy type)
fig.add_trace(go.Histogram(x=df['BMI'], name='BMI', marker_color='#EF553B'), row=1, col=2)

# Gender Pie Chart (domain type)
gender_counts = df['Gender'].value_counts()
fig.add_trace(go.Pie(labels=gender_counts.index, values=gender_counts.values, name='Gender', hole=0.3), row=1, col=3)

fig.update_layout(title_text='Patient Demographics Analysis', showlegend=False)
fig.show()


# Symptom Prevalence Analysis (This part was already correct)
symptom_df = df[symptom_cols].apply(lambda x: x.value_counts()).T.loc[:, 'Present'].sort_values(ascending=False)

fig2 = px.bar(
    symptom_df,
    x=symptom_df.index,
    y=symptom_df.values,
    title='Prevalence of Symptoms Among Patients',
    labels={'x': 'Symptom', 'y': 'Number of Patients Presenting Symptom'},
    color=symptom_df.values,
    color_continuous_scale='sunset'
)
fig2.show()

# %%
# Bivariate Analysis: Continuous Features vs. Fibrosis Stage
continuous_features = ['Age', 'BMI', 'RNA_Base', 'WBC', 'RBC', 'Plat']

# Create a 2x3 grid of subplots
fig = make_subplots(
    rows=2, cols=3,
    subplot_titles=continuous_features
)

# Loop through the features and add a Box plot for each
for i, feature in enumerate(continuous_features):
    row, col = (i // 3) + 1, (i % 3) + 1
    
    # Add a Plotly Box trace instead of a Seaborn plot
    fig.add_trace(
        go.Box(
            y=df[feature], 
            x=df['Fibrosis_Stage_Label'], # Use the readable label
            name=feature,
            marker_color=px.colors.qualitative.Vivid[i] # Assign a color
        ),
        row=row, col=col
    )

# Update the layout for a clean look
fig.update_layout(
    title_text='Continuous Features vs. Liver Fibrosis Stage',
    showlegend=False, # Hide legend as titles are enough
    height=700 # Adjust height for better spacing
)

fig.show()

# %%
# In[12]:
# Select only the original numerical columns for the correlation matrix
numerical_df = df.select_dtypes(include=np.number)

# Calculate the correlation matrix
corr_matrix = numerical_df.corr()

# Create the heatmap
plt.figure(figsize=(20, 16))
sns.heatmap(
    corr_matrix, 
    annot=True, 
    fmt='.2f', 
    cmap='coolwarm', 
    linewidths=0.5
)
plt.title('Correlation Matrix of Numerical Features', fontsize=20)
plt.show()

# %%
# In[13]:
# --- ALT Levels Over Time ---
alt_cols = ['ALT_1', 'ALT_4', 'ALT_12', 'ALT_24', 'ALT_36', 'ALT_48']
alt_df = df.groupby('Fibrosis_Stage_Label')[alt_cols].mean().T
alt_df.index = [1, 4, 12, 24, 36, 48] # Set index to weeks for plotting

# --- RNA Levels Over Time ---
rna_cols = ['RNA_Base', 'RNA_4', 'RNA_12', 'RNA_EOT', 'RNA_EF']
rna_df = df.groupby('Fibrosis_Stage_Label')[rna_cols].mean().T
rna_df.index = [0, 4, 12, 24, 52] # Rough week mapping: EOT~24w, EF~52w

# --- Plotting ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# ALT Plot
alt_df.plot(kind='line', marker='o', ax=ax1)
ax1.set_title('Average ALT Levels During Treatment by Fibrosis Stage', fontsize=16)
ax1.set_xlabel('Weeks of Treatment')
ax1.set_ylabel('Mean ALT Level')
ax1.legend(title='Fibrosis Stage')
ax1.grid(True)

# RNA Plot
rna_df.plot(kind='line', marker='x', ax=ax2)
ax2.set_title('Average RNA Levels During Treatment by Fibrosis Stage', fontsize=16)
ax2.set_xlabel('Weeks of Treatment')
ax2.set_ylabel('Mean RNA (Viral Load)')
ax2.legend(title='Fibrosis Stage')
ax2.grid(True)

plt.tight_layout()
plt.show()
